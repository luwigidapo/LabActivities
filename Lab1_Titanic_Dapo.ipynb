# %% [markdown]
# <a href="https://colab.research.google.com/github/luwigidapo/LabActivities/blob/main/Lab1_Titanic_Dapo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Laboratory Activity Sample Output

# %%
import pandas as pd

pd.read_csv()

# %% [markdown]
# ## This is where you will put your answers in Question 1

# %%
import pandas as pd

df = pd.read_csv("/content/train - train.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## This is where you will put your answers in Question 2

# %%
df.isnull().sum()

df['Age'] = df['Age'].fillna(df['Age'].mean())

df['Age'] = df['Age'].astype(int)

if 'Cabin' in df.columns:
    df.drop(columns=['Cabin'], inplace=True)

df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# %% [markdown]
# ## This is where you will put your answers in Question 3

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df["Survived"].mean()
# Out:
# 0.3838383838383838

# %% [markdown]
# ## This is where you will put your answers in Question 4

# %%
import matplotlib.pyplot as plt
plt.hist(df[df["Survived"] == 1]["Age"].dropna(), bins=20, alpha=0.5, label="Survived")
plt.hist(df[df["Survived"] == 0]["Age"].dropna(), bins=20, alpha=0.5, label="Did Not Survive")
plt.legend()
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# #Explanations

# %%
import pandas as pd

df = pd.read_csv("/content/train - train.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #Question 1: Understanding Decomposition
#
# This question focuses on Decomposition, which involves breaking down the task into smaller, manageable steps. The main goal is to load and process the Titanic dataset in Jupyter Notebook. The process includes:
#
#
#
# 1.   Downloading the Titanic dataset from Kaggle.
# 2.   Renaming the file as "titanic.csv" for consistency.
# 3.   Making a copy of the sample output provided in Google Classroom and renaming as instructed
# 4.   Uploading titanic.csv to Jupyter Notebook or Google Colab.
# 5.   Running the required code to load and view the dataset.
#
# # Code Explanation
# ` import pandas as pd`
#
# I imported the Pandas library, which is essential for loading, manipulating, and analyzing data in Python.
#
# `df = pd.read_csv("/content/train - train.csv")`
#
# I used this command to read the Titanic dataset from the specified file path (/content/train - train.csv). It loads the data into a Pandas DataFrame (df), allowing me to store and analyze it in a structured format.
#
# `df.head()`
#
# To quickly check if the dataset loaded correctly, I used df.head(), which displays the first five rows by default. If I wanted to see more, I could specify a number inside the parentheses (e.g., df.head(10)).

# %%
df.isnull().sum()
df['Age'] = df['Age'].fillna(df['Age'].mean())
df['Age'] = df['Age'].astype(int)
if 'Cabin' in df.columns:
    df.drop(columns=['Cabin'], inplace=True)
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# %% [markdown]
# #Question 2: Understanding Pattern Recognition
#
# Pattern Recognition helps identify similarities in the dataset, allowing for more efficient data processing and better algorithm performance. One key step is detecting and handling missing values to ensure accurate analysis.
#
#
# 1. Identifying Missing Values
#
# ```
# # df.isnull().sum()
#
# ```
# I used this command to count the number of missing values in each column. This helped me identify potential gaps in the dataset that could affect accuracy. After running this, I found that the Age, Cabin, and Embarked columns had missing values.
#
#
# 2. Handling Missing Values
#
# ```
# # df['Age'] = df['Age'].fillna(df['Age'].mean())
#
# ```
# Since Age is a numerical value, I decided to fill in the missing values using the average age of all passengers. This ensures that the dataset remains balanced without introducing bias.
#
#
# ```
# # df['Age'] = df['Age'].astype(int)
#
#
# ```
# After filling in the missing values, I noticed that some ages had decimal values. To maintain consistency, I converted them to whole numbers (integers).
#
#
#
# ```
# # df.drop(columns=['Cabin'], inplace=True)
#
# ```
#
# The Cabin column had too many missing values, making it difficult to extract meaningful insights. Since it wasn’t useful for my analysis, I removed it from the dataset.
#
#
#
# ```
# # df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])
#
# ```
#
# The Embarked column represents the port where passengers boarded the Titanic. To fill in the missing values, I used the most frequently occurring value (mode), ensuring consistency across the dataset.

# %%
df['Survived'].value_counts()
df["Survived"].mean()
# Out:
# 0.3838383838383838

# %% [markdown]
# #
